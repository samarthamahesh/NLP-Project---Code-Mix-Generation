# %%
import nltk
nltk.download('punkt')
import numpy as np
import string
from nltk.util import ngrams
import re
import pickle
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import tensorflow as tf
import math
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
train_path = "/content/sample_data/train_CM.txt"
train_file = open(train_path, "r")
count=0
train_data=""
tokens=[]
five_grams=[]


for lines in train_file:
  ss = lines.isspace()
  if (not ss):
    lines = lines.replace("<unk>","") 
    # Remove punctuations
    new_line = re.sub("[^a-zA-Z0-9 ]", "", lines).lower().strip()
    # Removing punctuations, converting to lower case
    # new_line = "".join([char for char in lines if char not in string.punctuation]).lower().strip()+"\n"
    train_data += new_line + "\n"
    for i in range(0,len(new_line.split())):
        temp1 = new_line.split()[i]
        tokens.append(temp1)
        if (i < len(new_line.split())-4): 
          temp4 = [new_line.split()[i+j] for j in range(0,5)]
          five_grams.append(temp4)
    count+=1
    if (count>10000): break


train_file.close()

# %%
print(len(train_data.split('\n')))
# Out:
# 10002

# %%
tokens.append("UNK")
print(len(set(tokens)))
# Out:
# 21196

# %%
# create integer-to-token mapping
int2token = {}

count = 0
for w in set(tokens):
  int2token[count] = w
  count+= 1

# create token-to-integer mapping
token2int = {t: i for i, t in int2token.items()}

print(len(token2int),len(int2token))
# Out:
# 21196 21196

# %%
print(token2int)
print(int2token)
# Out:
# {'aslilta': 0, 'btau': 1, 'chhutta': 2, 'neil': 3, 'sdi': 4, 'chalaaye': 5, 'kreena': 6, 'fade': 7, 'arrested': 8, 'tbb': 9, 'angrezon': 10, 'isharo': 11, 'seek': 12, 'kugh': 13, 'ziada': 14, 'lenge': 15, 'mody': 16, 'prey': 17, 'brabr': 18, 'dooooooo': 19, 'heye': 20, 'protests': 21, 'waah': 22, 'kanooni': 23, 'dhekna': 24, 'karten': 25, 'hataya': 26, 'unhone': 27, 'smbhal': 28, 'patriot': 29, 'khelen': 30, 'pension': 31, '36': 32, 'maarte': 33, 'cahata': 34, 'chilaate': 35, 'khuly': 36, 'hard': 37, 'has': 38, 'aadim': 39, 'rahethe': 40, 'dekhte': 41, 'galey': 42, 'kerty': 43, 'gst': 44, '72': 45, 'salia': 46, 'inkaa': 47, 'bhool': 48, 'deson': 49, 'fudu': 50, 'kadi': 51, 'question': 52, 'chootiya': 53, 'dekhe': 54, 'amitab': 55, 'natni': 56, 'wagh': 57, 'kamay': 58, 'banjay': 59, 'dikkat': 60, 'illuminati': 61, 'marg': 62, 'taab': 63, 'aginst': 64, 'ayese': 65, 'duryodhan': 66, 'gaao': 67, 'pecha': 68, 'looted': 69, 'dham': 70, 'pahnaya': 71, 'pahan': 72, 'jaghh': 73, 'chelo': 74, 'dane': 75, 'padhenge': 76, 'jerk': 77, 'fachi': 78, '1cr': 79, 'pepel': 80, 'pagla': 81, 'phd': 82, 'kanpur': 83, 'dikhadete': 84, 'goliyon': 85, 'biwi': 86, 'pls': 87, 'unper': 88, 'biwiyo': 89, 'kidr': 90, 'pry': 91, 'defference': 92, 'rounder': 93, 'stack': 94, 'mobail': 95, 'part': 96, 'giya': 97, 'sarein': 98, 'nhe': 99, 'patelon': 100, 'hafte': 101, 'bhatnagar
# {0: 'aslilta', 1: 'btau', 2: 'chhutta', 3: 'neil', 4: 'sdi', 5: 'chalaaye', 6: 'kreena', 7: 'fade', 8: 'arrested', 9: 'tbb', 10: 'angrezon', 11: 'isharo', 12: 'seek', 13: 'kugh', 14: 'ziada', 15: 'lenge', 16: 'mody', 17: 'prey', 18: 'brabr', 19: 'dooooooo', 20: 'heye', 21: 'protests', 22: 'waah', 23: 'kanooni', 24: 'dhekna', 25: 'karten', 26: 'hataya', 27: 'unhone', 28: 'smbhal', 29: 'patriot', 30: 'khelen', 31: 'pension', 32: '36', 33: 'maarte', 34: 'cahata', 35: 'chilaate', 36: 'khuly', 37: 'hard', 38: 'has', 39: 'aadim', 40: 'rahethe', 41: 'dekhte', 42: 'galey', 43: 'kerty', 44: 'gst', 45: '72', 46: 'salia', 47: 'inkaa', 48: 'bhool', 49: 'deson', 50: 'fudu', 51: 'kadi', 52: 'question', 53: 'chootiya', 54: 'dekhe', 55: 'amitab', 56: 'natni', 57: 'wagh', 58: 'kamay', 59: 'banjay', 60: 'dikkat', 61: 'illuminati', 62: 'marg', 63: 'taab', 64: 'aginst', 65: 'ayese', 66: 'duryodhan', 67: 'gaao', 68: 'pecha', 69: 'looted', 70: 'dham', 71: 'pahnaya', 72: 'pahan', 73: 'jaghh', 74: 'chelo', 75: 'dane', 76: 'padhenge', 77: 'jerk', 78: 'fachi', 79: '1cr', 80: 'pepel', 81: 'pagla', 82: 'phd', 83: 'kanpur', 84: 'dikhadete', 85: 'goliyon', 86: 'biwi', 87: 'pls', 88: 'unper', 89: 'biwiyo', 90: 'kidr', 91: 'pry', 92: 'defference', 93: 'rounder', 94: 'stack', 95: 'mobail', 96: 'part', 97: 'giya', 98: 'sarein', 99: 'nhe', 100: 'patelon', 101: 'hafte', 102: 'bhatnagar', 103: 'building', 104: 'newspaper', 105: 'undrwear', 106: 'swar', 107: 'jitnay', 108: 'blockbuster', 109: 'pish', 110: 'netagan', 111: 'saif', 112: 'ths', 113: 'thori', 114: 'kashi', 115: 'layege', 116: 'bacchae', 117: 'pampering', 118: 'krna', 119: 'hrs', 120: 'jio4g', 121: 'dramay', 122: 'thakns', 123: 'qayam', 124: 'gotale', 125: 'pnga', 126: 'navab', 127: 'kabada', 128: 'bindi', 129: 'balancing', 130: 'natak', 131: 'cancal', 132: 'ka', 133: 'vedas', 134: 'hindustanion', 135: 'doud', 136: 'indean', 137: 'hoki', 138: 'politition', 139: 'tumloga', 140: 'haathi', 141: 'koe', 142: 'isare', 143: 'aayege', 144: 'katai', 145: 'huye', 146: 'modiii', 147: 'bkwas', 148: 'sbr', 149: 'john', 150: 'yato', 151: 'cbse', 152: 'leg', 153: 'mem', 154: 'ceo', 155: 'wallpaper', 156: 'nashedi', 157: 'seduction', 158: 'dakar', 159: 'dpt', 160: 'deth', 161: 'bane', 162: 'chahiyen', 163: 'balooch', 164: 'paheli', 165: 'maderchod', 166: 'hatane', 167: 'energy', 168: 'banadiya', 169: 'neeraja', 170: 'kuchhu', 171: 'kayse', 172: 'indiaya', 173: 'bnde', 174: 'finacial', 175: 'sak', 176: 'define', 177: 'lomdi', 178: 'jangale', 179: 'mata', 180: 'aesei', 181: 'harkten', 182: 'dalalo', 183: 'year', 184: 'sire', 185: 'logh', 186: 'leptop', 187: 'churaya', 188: 'fayada', 189: 'aha', 190: 'raheja', 191: 'illetracy', 192: 'sukha', 193: 'assure', 194: 'tem', 195: 'networking', 196: 'samay', 197: 'lgayenge', 198: 'kuj', 199: 'shem', 200: 'bakawas', 201: 'zeeshan', 202: 'jaaega', 203: 'sahayk', 204: 'pehchanoge', 205: 'rakhha', 206: 'jula', 207: 'visa', 208: 'barobar', 209: 'jana', 210: 'dram', 211: 'kaamyaab', 212: 'chalayega', 213: 'chakna', 214: 'dekhtey', 215: 'jalebi', 216: 'homo', 217: 'sahkti', 218: 'mull', 219: 'diwakar', 220: 'thankx', 221: 'discount', 222: 'bhikhario', 223: 'wadi', 224: 'phly', 225: 'asutosh', 226: 'regards', 227: 'kicher', 228: 'week', 229: 'prodof', 230: 'ashki', 231: 'kijeye', 232: 'klnk', 233: 'super', 234: 'barabari', 235: 'alg', 236: 'bdao', 237: 'trf', 238: 'gov', 239: 'rhny', 240: 'chaand', 241: 'awareness', 242: 'rishte', 243: 'underground', 244: 'karan', 245: 'aunty', 246: 'galt', 247: 'shoru', 248: 'aajate', 249: 'china', 250: 'sabase', 251: 'ink', 252: 'congressiyon', 253: 'mahir', 254: 'rach', 255: 'merko', 256: 'badhte', 257: 'banake', 258: 'hud', 259: 'rakhsha', 260: 'aastin', 261: 'chalo', 262: 'pahuchte', 263: 'meee', 264: 'bm', 265: 'badshah', 266: 'uu', 267: 'antinational', 268: 'madarchodo', 269: 'firku', 270: 'surprise', 271: 'hahut', 272: 'accuse', 273: 'achchhe', 274: 'revolutionary', 275: 'hti', 276: 'jub', 277: 'cheeze', 278: 'isje', 279: 'tabhi', 280: 'sahil', 2 ...

# %%
vocab_size = len(set(tokens))
print(vocab_size)
# Out:
# 21196

# %%
import collections

word_counter = collections.Counter()
for term in tokens:
    word_counter.update({term: 1})

# %%
ind=0
for i in word_counter:
  if (word_counter[i]==1): 
    ind+=1

print(ind)
# Out:
# 11764

# %%
common_words = word_counter.most_common(vocab_size-10000) # Most common terms
print(word_counter.most_common(100))
# Out:
# [('hai', 5277), ('to', 3390), ('ko', 3073), ('ki', 2994), ('me', 2442), ('ka', 2405), ('h', 2359), ('ke', 2249), ('se', 2014), ('ho', 1772), ('nahi', 1625), ('bhi', 1497), ('k', 1486), ('ye', 1442), ('hi', 1431), ('or', 1198), ('aur', 1159), ('kya', 1132), ('he', 1073), ('is', 1048), ('nhi', 1016), ('aap', 954), ('kar', 941), ('koi', 889), ('jo', 774), ('ji', 746), ('ne', 729), ('news', 714), ('liye', 706), ('india', 689), ('ek', 687), ('na', 661), ('modi', 632), ('log', 616), ('tak', 610), ('the', 608), ('aaj', 564), ('kuch', 564), ('par', 557), ('media', 556), ('in', 544), ('tha', 520), ('sab', 519), ('ab', 518), ('do', 505), ('bhai', 495), ('bjp', 493), ('ha', 491), ('desh', 485), ('hain', 475), ('party', 473), ('wo', 454), ('ya', 451), ('chahiye', 450), ('and', 448), ('of', 444), ('kr', 440), ('i', 432), ('raha', 425), ('kiya', 411), ('u', 401), ('hota', 396), ('a', 392), ('rahe', 391), ('tum', 380), ('baat', 374), ('m', 372), ('mai', 371), ('sir', 369), ('wale', 354), ('hoga', 353), ('you', 351), ('logo', 343), ('kisi', 339), ('pe', 333), ('kam', 332), ('karo', 329), ('v', 329), ('diya', 319), ('apne', 315), ('are', 312), ('de', 310), ('pakistan', 305), ('agar', 298), ('good', 291), ('sirf', 279), ('but', 275), ('delhi', 269), ('main', 268), ('b', 265), ('jab', 260), ('sahi', 259), ('teacher', 255), ('yeh', 252), ('ni', 252), ('s', 251), ('kejriwal', 250), ('pr', 243), ('indian', 240), ('sath', 239)]

# %%
# create inputs and targets (x and y)
x = []
y = []

for s in five_grams:
    x.append(s[:-1])
    y.append(s[1:])

print(x[:10])
print(y[:10])
# Out:
# [['ye', 'to', 'hona', 'hi'], ['to', 'hona', 'hi', 'tha'], ['hona', 'hi', 'tha', 'kabhi'], ['hi', 'tha', 'kabhi', 'kisi'], ['tha', 'kabhi', 'kisi', 'neta'], ['kabhi', 'kisi', 'neta', 'ko'], ['kisi', 'neta', 'ko', 'saja'], ['neta', 'ko', 'saja', 'mili'], ['ko', 'saja', 'mili', 'hi'], ['saja', 'mili', 'hi', 'always']]
# [['to', 'hona', 'hi', 'tha'], ['hona', 'hi', 'tha', 'kabhi'], ['hi', 'tha', 'kabhi', 'kisi'], ['tha', 'kabhi', 'kisi', 'neta'], ['kabhi', 'kisi', 'neta', 'ko'], ['kisi', 'neta', 'ko', 'saja'], ['neta', 'ko', 'saja', 'mili'], ['ko', 'saja', 'mili', 'hi'], ['saja', 'mili', 'hi', 'always'], ['mili', 'hi', 'always', 'clean']]

# %%
# def get_integer_seq(seq):
#   temp=[]
#   for w in seq:
#     if w in common_words:
#       temp.append(token2int[w])
#     else:
#       temp.append(token2int['UNK'])
#   return temp

# def get_integer_seq_unk(seq):
#   temp=[]
#   for w in seq:
#     if w in common_words:
#       temp.append(token2int[w])
#     else:
#       if w in token2int: temp.append(token2int[w])
#       else: temp.append(token2int['UNK'])
#   return temp

def get_integer_seq(seq):
    ret = []
    for w in seq:
        if w in token2int:
            ret.append(token2int[w])
        else:
            ret.append(token2int['UNK'])
    
    return ret

# %%
# convert text sequences to integer sequences
x_int_ = [get_integer_seq(i) for i in x]
y_int_ = [get_integer_seq(i) for i in y]

# convert lists to numpy arrays
x_int = np.array(x_int_)
y_int = np.array(y_int_)

# %%
print(x_int.shape,y_int.shape)
print(x_int[10:],y_int[10:])
# Out:
# (155157, 4) (155157, 4)
# [[ 4759 13601  5291 20347]
#  [19643 20650 16299  8326]
#  [20650 16299  8326 16069]
#  ...
#  [15416   507  6047 19009]
#  [  507  6047 19009 15401]
#  [ 6047 19009 15401 13428]] [[13601  5291 20347 12539]
#  [20650 16299  8326 16069]
#  [16299  8326 16069 14053]
#  ...
#  [  507  6047 19009 15401]
#  [ 6047 19009 15401 13428]
#  [19009 15401 13428 15401]]

# %%
print(token2int['UNK'])
# Out:
# 20696

# %%
def get_batches(arr_x, arr_y, batch_size): 
    # iterate through the arrays
    prv = 0
    for n in range(batch_size, arr_x.shape[0], batch_size):
      x = arr_x[prv:n,:]
      y = arr_y[prv:n,:]
      prv = n
      yield x, y

# %%
class WordLSTM(nn.Module):
    def __init__(self, n_hidden=256, n_layers=4, drop_prob=0.3, lr=0.001):
        super().__init__()

        self.drop_prob = drop_prob
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.lr = lr
        
        self.emb_layer = nn.Embedding(vocab_size, 200)

        ## define the LSTM
        self.lstm = nn.LSTM(200, n_hidden, n_layers, 
                            dropout=drop_prob, batch_first=True)
        
        ## define a dropout layer
        self.dropout = nn.Dropout(drop_prob)
        
        ## define the fully-connected layer
        self.fc = nn.Linear(n_hidden, vocab_size)      
    
    def forward(self, x, hidden):
        ''' Forward pass through the network. 
            These inputs are x, and the hidden/cell state `hidden`. '''

        ## pass input through embedding layer
        embedded = self.emb_layer(x)     
        
        ## Get the outputs and the new hidden state from the lstm
        lstm_output, hidden = self.lstm(embedded, hidden)
        
        ## pass through a dropout layer
        out = self.dropout(lstm_output)
        
        #out = out.contiguous().view(-1, self.n_hidden) 
        out = out.reshape(-1, self.n_hidden) 

        ## put "out" through the fully-connected layer
        out = self.fc(out)

        # return the final output and the hidden state
        return out, hidden
    
    
    def init_hidden(self, batch_size):
        ''' initializes hidden state '''
        # Create two new tensors with sizes n_layers x batch_size x n_hidden,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data

        # if GPU is available
        if (torch.cuda.is_available()):
          hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda(),
                    weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda())
        
        # if GPU is not available
        else:
          hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_(),
                    weight.new(self.n_layers, batch_size, self.n_hidden).zero_())
        
        return hidden

# %%
# instantiate the model
net = WordLSTM()

# push the model to GPU (avoid it if you are not using the GPU)
net.cuda()

print(net)
# Out:
# WordLSTM(
#   (emb_layer): Embedding(21196, 200)
#   (lstm): LSTM(200, 256, num_layers=4, batch_first=True, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=256, out_features=21196, bias=True)
# )

# %%
def train(net, epochs=10, batch_size=32, lr=0.001, clip=1, print_every=32):
    
    # optimizer
    opt = torch.optim.Adam(net.parameters(), lr=lr)
    
    # loss
    criterion = nn.CrossEntropyLoss()
    
    # push model to GPU
    net.cuda()
    
    counter = 0

    net.train()
    for e in range(epochs):

        # initialize hidden state
        h = net.init_hidden(batch_size)

        for x, y in get_batches(x_int, y_int, batch_size):
            counter+= 1
            # convert numpy arrays to PyTorch arrays
            inputs, targets = torch.from_numpy(x), torch.from_numpy(y)
            
            # push tensors to GPU
            inputs, targets = inputs.cuda(), targets.cuda()

            # detach hidden states
            h = tuple([each.data for each in h])

            # zero accumulated gradients
            net.zero_grad()
            
            # get the output from the model
            output, h = net(inputs, h)
            
            # calculate the loss and perform backprop
            loss = criterion(output, targets.view(-1))

            # store loss of each epoch
            losses.append(loss)

            # back-propagate error
            loss.backward()

            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(net.parameters(), clip)

            # update weigths
            opt.step()            
            
            if counter % print_every == 0:
            
                print("Epoch: {}/{}...".format(e+1, epochs), 
                      "Step: {}...".format(counter))

# %%
# predict next token
def predict_prob(net, tkn, trg, h=None):
            
    # tensor inputs
    if tkn in token2int:
      x = np.array([[token2int[tkn]]])
    else:
      x = np.array([[token2int['UNK']]])

    inputs = torch.from_numpy(x)

    # push to GPU
    inputs = inputs.cuda()

    # detach hidden state from history
    h = tuple([each.data for each in h])

    # get the output of the model
    out, h = net(inputs, h)

    # get the token probabilities
    p = F.softmax(out, dim=1).data

    p = p.cpu()

    p = p.numpy()
    p = p.reshape(p.shape[1],)

    if trg in token2int:
        prob = p[token2int[trg]]
    else:
        prob = p[token2int['UNK']]

    return h, prob


# function to calculate perplexity
def get_prob(net, x, y):

    # push to GPU
    net.cuda()

    net.eval()

    # batch size is 1
    h = net.init_hidden(1)

    N = len(x)
    tmp = 1

# Epoch: 13/15... Step: 59648...
# Epoch: 13/15... Step: 59904...
# Epoch: 13/15... Step: 60160...
# Epoch: 13/15... Step: 60416...
# Epoch: 13/15... Step: 60672...
# Epoch: 13/15... Step: 60928...
# Epoch: 13/15... Step: 61184...
# Epoch: 13/15... Step: 61440...
# Epoch: 13/15... Step: 61696...
# Epoch: 13/15... Step: 61952...
# Epoch: 13/15... Step: 62208...
# Epoch: 13/15... Step: 62464...
# Epoch: 13/15... Step: 62720...
# Epoch: 13/15... Step: 62976...
# Epoch: 14/15... Step: 63232...
# Epoch: 14/15... Step: 63488...
# Epoch: 14/15... Step: 63744...
# Epoch: 14/15... Step: 64000...
# Epoch: 14/15... Step: 64256...
# Epoch: 14/15... Step: 64512...
# Epoch: 14/15... Step: 64768...
# Epoch: 14/15... Step: 65024...
# Epoch: 14/15... Step: 65280...
# Epoch: 14/15... Step: 65536...
# Epoch: 14/15... Step: 65792...
# Epoch: 14/15... Step: 66048...
# Epoch: 14/15... Step: 66304...
# Epoch: 14/15... Step: 66560...
# Epoch: 14/15... Step: 66816...
# Epoch: 14/15... Step: 67072...
# Epoch: 14/15... Step: 67328...
# Epoch: 14/15... Step: 67584...
# Epoch: 14/15... Step: 67840...
# Epoch: 15/15... Step: 68096...
# Epoch: 15/15... Step: 68352...
# Epoch: 15/15... Step: 68608...
# Epoch: 15/15... Step: 68864...
# Epoch: 15/15... Step: 69120...
# Epoch: 15/15... Step: 69376...
# Epoch: 15/15... Step: 69632...
# Epoch: 15/15... Step: 69888...
# Epoch: 15/15... Step: 70144...
# Epoch: 15/15... Step: 70400...
# Epoch: 15/15... Step: 70656...
# Epoch: 15/15... Step: 70912...
# Epoch: 15/15... Step: 71168...
# Epoch: 15/15... Step: 71424...
# Epoch: 15/15... Step: 71680...
# Epoch: 15/15... Step: 71936...
# Epoch: 15/15... Step: 72192...
# Epoch: 15/15... Step: 72448...
# Epoch: 15/15... Step: 72704...

# %%
print(losses[0].item())
# Out:
# 9.96765422821045

# %%
torch.save(net, '/content/sample_data/model1')

# %%
import pandas as pd
data = {
    'Epoch': [i for i in range(1,16)]
}

temp = []
for i in range(0,15):
  temp.append(losses[i].item())

data['Loss']= [i for i in temp]
df = pd.DataFrame(data,columns=['Epoch','Loss'])
print (df)
# Out:
#     Epoch      Loss
# 0       1  9.967654
# 1       2  9.957234
# 2       3  9.955852
# 3       4  9.946695
# 4       5  9.945626
# 5       6  9.925704
# 6       7  9.927316
# 7       8  9.940773
# 8       9  9.882046
# 9      10  9.848527
# 10     11  9.832067
# 11     12  9.782310
# 12     13  9.578766
# 13     14  9.421479
# 14     15  9.626632

# %%
df.plot(x ='Epoch', y='Loss', kind = 'line')

# %%
word_counter['UNK'] = 10000

# %%
train_path = "/content/sample_data/train_CM.txt"
train_file = open(train_path, "r")
count=0
perp=0
avg_perp=0

for lines in train_file:   
  if (count>10000): break
  ss = lines.isspace()
  if (not ss):
    lines = lines.replace("<unk>","")
    new_line = re.sub("[^a-zA-Z0-9 ]", "", lines).lower().strip()
    # new_line = "".join([char for char in lines if char not in string.punctuation]).lower().strip()+"\n"
    output=0
    # print(new_line)
    for i in range(0,len(new_line.split())):
      test_x=[]
      test_y=[]
      if (i < len(new_line.split())-4): 
          temp = [new_line.split()[i+j] for j in range(0,5)]
          temp_x = temp[:-1]
          temp_y = temp[1:]
          test_x = get_integer_seq(temp_x)
          test_y = get_integer_seq(temp_y)
          output += get_prob(net, test_x, test_y)
          # print("5 gram",output)
    if len(new_line.split())!=0:
      perp = get_perp(output,len(new_line.split()))
      # print("perp",perp)
    avg_perp+=perp
    count+=1

train_file.close()
avg_perp = avg_perp/count
print("avg perp",avg_perp)
# Out:
# avg perp 2.4409064381639178e+25

# %%
test_path = "/content/sample_data/test_CM.txt"
test_file = open(test_path, "r")
count=0
test_data=""
perp=0
avg_perp=0

for lines in test_file:
  # if(count>100): break
  ss = lines.isspace()
  if (not ss):
    lines = lines.replace("<unk>","")
    new_line = re.sub("[^a-zA-Z0-9 ]", "", lines).lower().strip()
    # new_line = "".join([char for char in lines if char not in string.punctuation]).lower().strip()+"\n"
    output=0
    for i in range(0,len(new_line.split())):
      test_x=[]
      test_y=[]
      if (i < len(new_line.split())-4): 
          temp = [new_line.split()[i+j] for j in range(0,5)]
          temp_x = temp[:-1]
          temp_y = temp[1:]
          test_x = get_integer_seq(temp_x)
          test_y = get_integer_seq(temp_y)
          output += get_prob(net, test_x, test_y)
    perp = get_perp(output,len(new_line.split()))
    avg_perp+=perp
    count+=1

test_file.close()
avg_perp = avg_perp/count
print(avg_perp)
# Out:
# 2.50884831429142e+25

# %%
# predict next token
def predict(net, tkn, h=None):
         
  # tensor inputs
  if tkn in token2int:
      x = np.array([[token2int[tkn]]])
  else:
      x = np.array([[token2int['UNK']]])
  inputs = torch.from_numpy(x)
  
  # push to GPU
  inputs = inputs.cuda()

  # detach hidden state from history
  h = tuple([each.data for each in h])

  # get the output of the model
  out, h = net(inputs, h)

  # get the token probabilities
  p = F.softmax(out, dim=1).data

  p = p.cpu()

  p = p.numpy()
  p = p.reshape(p.shape[1],)

  # get indices of top 3 values
  top_n_idx = p.argsort()[-3:][::-1]

  sampled_token_index = token2int['UNK']
  while int2token[sampled_token_index]=='UNK':
    # randomly select one of the three indices
    sampled_token_index = top_n_idx[random.sample([0,1,2],1)[0]]

  # return the encoded value of the predicted char and the hidden state
  return int2token[sampled_token_index], h
  
# function to generate text
def sample(net, size, prime='it is'):
        
    # push to GPU
    net.cuda()
    
    net.eval()

    # batch size is 1
    h = net.init_hidden(1)

    toks = prime.split()

    # predict next token
    for t in prime.split():
      token, h = predict(net, t, h)
    
    toks.append(token)

    # predict subsequent tokens
    for i in range(size-1):
        token, h = predict(net, toks[-1], h)
        toks.append(token)

    return ' '.join(toks)

# %%
i=0
while (i!=4):
  i+=1
  print(sample(net, 10, prime="comments"))
# Out:
# comments me hai jo ek hi jarurat ho to kya farak
# comments ke bare ke liye darne ka naam kharab kar rhe
# comments ke sath hai jo bhi to fir to kya farak
# comments ki image ka bhi halat hai or ye to kya
